# %% [markdown]
# # Chapter 7: RandomForestRegressor

# %%
# from google.colab import drive
# drive.mount("/content/gdrive", force_remount=True)

# %%
# %cd '/content/gdrive/My Drive/LDS6_MachineLearning/practice/Chapter7_Random_Forest/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_excel("Iris.xls")
iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   iris         150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
iris.head(3)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth         iris
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
petalwidth = iris[['petalwidth']]
pentallength = iris['petallength']

# %%
plt.scatter(petalwidth, pentallength)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(petalwidth, pentallength,
                                                    test_size=0.20,random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor

# Create random forest resgressor object
rrf = RandomForestRegressor(n_estimators=100)
# Train model
model = rrf.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([4.19075201, 1.35478828, 5.64169762, 4.6995146 , 4.5868231 ,
#        1.57511424, 4.20067261, 5.64169762, 4.6995146 , 4.19075201,
#        5.44188214, 1.37111353, 1.43832306, 1.37111353, 1.35478828,
#        5.10390325, 6.30635   , 3.43169502, 4.20067261, 6.30635   ,
#        1.43832306, 5.31484343, 1.57511424, 5.79977183, 5.44188214,
#        5.64169762, 5.31484343, 5.64169762, 1.35478828, 1.43832306])

# %%
from sklearn.metrics import mean_squared_error

# %%
# Score
print("The R^2 train score is: ", model.score(X_train, y_train))
print("The R^2 test score is: ", model.score(X_test,y_test))
# tinh them mse
print("MSE (in train): ", mean_squared_error(y_train, model.predict(X_train)))
print("MSE (in test): ", mean_squared_error(y_test, y_pred))
# Out:
# The R^2 train score is:  0.964442180260746
# The R^2 test score is:  0.9398367319933354
# MSE (in train):  0.10827790706177425
# MSE (in test):  0.19717842608428693

# %%
# R^2 của cả train và test đều cao => model phù hợp với dữ liệu
# MSE thấp

# %%
df = pd.DataFrame({'Actual': pd.DataFrame(y_test.values)[0].values,
                   'Prediction': pd.DataFrame(y_pred)[0].values})
df.head()
# Out:
#    Actual  Prediction
# 0     4.7    4.190752
# 1     1.7    1.354788
# 2     6.9    5.641698
# 3     4.5    4.699515
# 4     4.8    4.586823

# %%
x_now = [[0.25]]
y_now = model.predict(x_now)
y_now
# Out:
# C:\Users\my computer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1.43832306])
